# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio
# **Rajesh Nethala**
# #Group Manager <br>
# *I love data science because I love data*<br>
# ###Print Hello World<br>

# %% [markdown]
# ```python
# print "Hello World"
# ```

# %% [markdown]
# ***
# - First item
# - Second item
# - Third item
# - Fourth item
# ***

# %% [markdown]
# 1. First item
# 2. Second item
# 3. Third item
# 4. Fourth item

# %%
[Home page of Jupyter]()
